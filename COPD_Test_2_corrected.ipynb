# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/COPDHealthy.zip','r') as zip_ref:
    zip_ref.extractall('audio_and_txt_files')

# %%
import numpy as np
import pandas as pd
import librosa
import librosa.display
import glob as gb
import matplotlib.pyplot as plt
import gc
sound_dir_loc=np.array(gb.glob("audio_and_txt_files/*.wav"))

# %%
def build_spectogram(file_path,sound_file_name):
    plt.interactive(False)
    file_audio_series,sr = librosa.load(file_path,sr=None)
    spec_image = plt.figure(figsize=[0.72,0.72])
    ax = spec_image.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    spectogram = librosa.feature.melspectrogram(y=file_audio_series, sr=sr)
    librosa.display.specshow(librosa.power_to_db(spectogram, ref=np.max))
    image_name  = 'spec_images/' + sound_file_name + '.jpg'
    plt.savefig(image_name, dpi=400, bbox_inches='tight',pad_inches=0)
    plt.close()
    spec_image.clf()
    plt.close(spec_image)
    plt.close('all')
    del file_path,sound_file_name,file_audio_series,sr,spec_image,ax,spectogram

# %%
import os
print(os.listdir('audio_and_txt_files'))
# Out:
# ['163_2b2_Pl_mc_AKGC417L.wav', '207_3b2_Lr_mc_AKGC417L.wav', '145_2b2_Pr_mc_AKGC417L.wav', '156_2b3_Ll_mc_AKGC417L.wav', '133_2p4_Ar_mc_AKGC417L.wav', '170_1b4_Al_mc_AKGC417L.wav', '185_1b1_Ar_sc_Litt3200.wav', '158_1p3_Pl_mc_AKGC417L.wav', '172_1b3_Al_mc_AKGC417L.wav', '146_8p3_Pl_mc_AKGC417L.wav', '138_2p2_Al_mc_AKGC417L.wav', '160_1b2_Pr_mc_AKGC417L.wav', '172_2b5_Pl_mc_AKGC417L.wav', '145_3b2_Ar_mc_AKGC417L.wav', 'COPDHealthy', '205_2b3_Ll_mc_AKGC417L.wav', '176_1b3_Tc_mc_AKGC417L.wav', '158_1p4_Ar_mc_AKGC417L.wav', '134_2b2_Al_mc_LittC2SE.wav', '180_1b4_Ar_mc_AKGC417L.wav', '104_1b1_Lr_sc_Litt3200.wav', '162_2b3_Al_mc_AKGC417L.wav', '158_2p3_Lr_mc_AKGC417L.wav', '107_3p2_Al_mc_AKGC417L.wav', '172_1b5_Ll_mc_AKGC417L.wav', '132_2b1_Lr_mc_LittC2SE.wav', '146_8p3_Lr_mc_AKGC417L.wav', '133_2p3_Tc_mc_AKGC417L.wav', '207_2b2_Pr_mc_AKGC417L.wav', '200_2p2_Pr_mc_AKGC417L.wav', '109_1b1_Pr_sc_Litt3200.wav', '207_3b2_Al_mc_AKGC417L.wav', '154_1b3_Ar_mc_AKGC417L.wav', '147_2b3_Pl_mc_AKGC417L.wav', '200_2p4_Pr_mc_AKGC417L.wav', '162_2b4_Pr_mc_AKGC417L.wav', '130_3p2_Pl_mc_AKGC417L.wav', '130_2b4_Lr_mc_AKGC417L.wav', '147_2b3_Ll_mc_AKGC417L.wav', '110_1p1_Pr_sc_Meditron.wav', '109_1b1_Ar_sc_Litt3200.wav', '133_3p2_Ar_mc_AKGC417L.wav', '200_2p4_Lr_mc_AKGC417L.wav', '205_3b4_Ar_mc_AKGC417L.wav', '130_3p3_Tc_mc_AKGC417L.wav', '166_1p1_Ar_sc_Meditron.wav', '200_3p4_Tc_mc_AKGC417L.wav', '107_3p2_Lr_mc_AKGC417L.wav', '130_1p2_Ar_mc_AKGC417L.wav', '213_2p2_Ar_mc_AKGC417L.wav', '178_1b6_Lr_mc_AKGC417L.wav', '172_1b3_Ll_mc_AKGC417L.wav', '147_2b3_Al_mc_AKGC417L.wav', '118_1b1_Pl_sc_Litt3200.wav', '187_1b1_Ll_sc_Meditron.wav', '209_1b1_Tc_sc_Meditron.wav', '221_2b1_Al_mc_LittC2SE.wav', '130_3p4_Tc_mc_AKGC417L.wav', '204_7p5_Lr_mc_AKGC417L.wav', '203_2p3_Tc_mc_AKGC417L.wav', '154_4b4_Lr_mc_AKGC417L.wav', '199_2b3_Ll_mc_LittC2SE.wav', '224_1b1_Tc_sc_Meditron.wav', '193_7b3_Tc_mc_AKGC417L.wav', '170_1b4_Pr_mc_AKGC417L.wav', '193_1b2_Pr_mc_AKGC417L.wav', '154_2b4_Pl_mc_AKGC417L.wav', '120_1b1_Ar_sc_Meditron.wav', '160_1b3_Lr_mc_AKGC417L.wav', '176_1b4_Al_mc_AKGC417L.wav', '170_1b3_Ll_mc_AKGC417L.wav', '106_2b1_Pl_mc_LittC2SE.wav', '151_3p2_Al_mc_AKGC417L.wav', '186_2b3_Pl_mc_AKGC417L.wav', '107_2b3_Pr_mc_AKGC417L.wav', '176_2b3_Ar_mc_AKGC417L.wav', '170_1b2_Tc_mc_AKGC417L.wav', '170_1b3_Al_mc_AKGC417L.wav', '146_2b4_Pr_mc_AKGC417L.wav', '138_1p4_Ar_mc_AKGC417L.wav', '107_2b4_Ar_mc_AKGC417L.wav', '174_1p2_Ar_mc_AKGC417L.wav', '157_1b1_Al_sc_Meditron.wav', '113_1b1_Pr_sc_Litt3200.wav', '130_2p5_Ar_mc_AKGC417L.wav', '162_2b4_Ar_mc_AKGC417L.wav', '170_2b2_Tc_mc_AKGC417L.wav', '193_1b2_Ar_mc_AKGC417L.wav', '138_1p3_Pr_mc_AKGC417L.wav', '178_1b6_Pr_mc_AKGC417L.wav', '200_2p3_Pl_mc_AKGC417L.wav', '147_2b4_Lr_mc_AKGC417L.wav', '141_1b2_Pr_mc_LittC2SE.wav', '120_1b1_Pl_sc_Meditron.wav', '186_2b2_Ar_mc_AKGC417L.wav', '112_1p1_Pl_sc_Litt3200.wav', '118_1b1_Ll_sc_Litt3200.wav', '186_2b3_Pr_mc_AKGC417L.wav', '218_1b1_Pl_sc_Meditron.wav', '176_1b4_Ar_mc_AKGC417L.wav', '130_1p3_Al_mc_AKGC417L.wav', '130_1p3_Lr_mc_AKGC417L.wav', '162_1b2_Al_mc_AKGC417L.wav', '127_1b1_Ar_sc_Meditron.wav', '138_1p3_Ar_mc_AKGC417L.wav', '146_2b2_Pl_mc_AKGC417L.wav', '133_2p3_Pl_mc_AKGC417L.wav', '158_1p3_Lr_mc_AKGC417L.wav', '130_3p3_Pr_mc_AKGC417L.wav', '225_1b1_Pl_sc_Meditron.wav', '177_1b4_Al_mc_AKGC417L.wav', '185_1b1_Lr_sc_Litt3200.wav', '107_2b4_Pl_mc_AKGC417L.wav', '205_4b2_Al_mc_AKGC417L.wav', '159_1b1_Al_sc_Meditron.wav', '151_2p2_Tc_mc_AKGC417L.wav', '186_2b3_Ar_mc_AKGC417L.wav', '151_2p4_Ar_mc_AKGC417L.wav', '180_1b4_Al_mc_AKGC417L.wav', '113_1b1_Lr_sc_Litt3200.wav', '107_2b5_Ar_mc_AKGC417L.wav', '130_2b4_Al_mc_AKGC417L.wav', '170_2b2_Pr_mc_AKGC417L.wav', '205_1b3_Ar_mc_AKGC417L.wav', '174_1p2_Tc_mc_AKGC417L.wav', '175_1b1_Al_sc_Litt3200.wav', '151_3p2_Lr_mc_AKGC417L.wav', '156_2b3_Lr_mc_AKGC417L.wav', '151_2p2_Lr_mc_AKGC417L.wav', '146_8p3_Pr_mc_AKGC417L.wav', '221_2b3_Ar_mc_LittC2SE.wav', '162_1b2_Pr_mc_AKGC417L.wav', '207_2b3_Pl_mc_AKGC417L.wav', '141_1b3_Al_mc_LittC2SE. ...

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/COPDHealthy.zip', 'r') as z:
    names = z.namelist()
    print(len(names))
    print(names[:10])
# Out:
# 829
# ['COPDHealthy/', 'COPDHealthy/102_1b1_Ar_sc_Meditron.wav', 'COPDHealthy/104_1b1_Al_sc_Litt3200.wav', 'COPDHealthy/104_1b1_Ar_sc_Litt3200.wav', 'COPDHealthy/104_1b1_Ll_sc_Litt3200.wav', 'COPDHealthy/104_1b1_Lr_sc_Litt3200.wav', 'COPDHealthy/104_1b1_Pl_sc_Litt3200.wav', 'COPDHealthy/104_1b1_Pr_sc_Litt3200.wav', 'COPDHealthy/106_2b1_Pl_mc_LittC2SE.wav', 'COPDHealthy/106_2b1_Pr_mc_LittC2SE.wav']

# %%
# !mv audio_and_txt_files/COPDHealthy/* audio_and_txt_files/
# !rmdir audio_and_txt_files/COPDHealthy

# %%
import os
files = os.listdir('audio_and_txt_files')
wav_files = [f for f in files if f.endswith('.wav')]
txt_files = [f for f in files if f.endswith('.txt')]
print(f'Total: {len(files)}')
print(f'.wav files: {len(wav_files)}')
print(f'.txt files: {len(txt_files)}')
# Out:
# Total: 829
# .wav files: 828
# .txt files: 0

# %%
import os

if not os.path.exists('spec_images'):
    os.makedirs('spec_images')

for file in sound_dir_loc:
    sfile_name = file.split('/')[-1].split('.')[0]
    build_spectogram(file,sfile_name)

gc.collect()
# Out:
# 39069

# %%
import os
files = os.listdir('audio_and_txt_files')
wav_files = [f for f in files if f.endswith('.wav')]
txt_files = [f for f in files if f.endswith('.txt')]
print(f'Total: {len(files)}')
print(f'.wav files: {len(wav_files)}')
print(f'.txt files: {len(txt_files)}')
# Out:
# Total: 829
# .wav files: 828
# .txt files: 0

# %%
patient_data=pd.read_csv('patient_diagnosis.csv', header=None, dtype=str)
patient_data.columns = ['ID', 'CLASS']
spectograms_dir_loc=np.array(gb.glob("spec_images/*.jpg"))

# %%
index = 0
for image in spectograms_dir_loc[index:]:
    image_name = image.split('/')[1]
    patient_id = image_name.split('_')[0]
    patient_condition = patient_data.loc[(patient_data['ID'] == patient_id)].iloc[0]['CLASS']
    # print(image_name,patient_id,patient_condition,sep=' ',end='\n')
    patient_data_all.loc[len(patient_data_all)] = [image_name, patient_condition]

del image_name,patient_id,patient_condition,index,image

# %%
patient_data_all = patient_data_all[
    patient_data_all['CLASS'].isin(['COPD', 'Healthy'])
].reset_index(drop=True)

print(patient_data_all['CLASS'].value_counts())
print('Total samples after filtering:', len(patient_data_all))
# Out:
# CLASS
# COPD       1586
# Healthy      70
# Name: count, dtype: int64
# Total samples after filtering: 1656

# %%
# !pip install keras-preprocessing
from sklearn.model_selection import train_test_split
trainset_df, testset_df = train_test_split(patient_data_all, test_size=0.2,stratify=patient_data_all['CLASS'], random_state=42)
from keras_preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,validation_split=0.25)
test_datagen = ImageDataGenerator(rescale = 1./255)
# Out:
# Requirement already satisfied: keras-preprocessing in /usr/local/lib/python3.13/dist-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.13/dist-packages (from keras-preprocessing) (2.1.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from keras-preprocessing) (1.17.0)

# %%
training_set = train_datagen.flow_from_dataframe(
    dataframe=trainset_df,
    directory="spec_images/",
    x_col="ID",
    y_col="CLASS",
    subset="training",
    batch_size=32,
    seed=42,
    shuffle=True,
    class_mode="binary",
    target_size=(64,64))

validation_set = train_datagen.flow_from_dataframe(
    dataframe=trainset_df,
    directory="spec_images/",
    x_col="ID",
    y_col="CLASS",
    subset="validation",
    batch_size=32,
    seed=42,
    shuffle=True,
    class_mode="binary",
    target_size=(64,64))

test_set = test_datagen.flow_from_dataframe(
    dataframe=testset_df,
    directory="spec_images/",
    x_col="ID",
    y_col=None,
    batch_size=32,
    seed=42,
    shuffle=False,
    class_mode=None,
    target_size=(64,64))
# Out:
# Found 993 validated image filenames belonging to 2 classes.
# Found 331 validated image filenames belonging to 2 classes.
# Found 332 validated image filenames.

# %%
from keras.models import Sequential
from keras.layers import Convolution2D, Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout,BatchNormalization

# %%
from sklearn.utils.class_weight import compute_class_weight
classes = np.unique(training_set.classes)
class_weights = compute_class_weight('balanced', classes=classes, y=training_set.classes)
class_weights = dict(zip(classes, class_weights))

# %%
classifier = Sequential()
classifier.add(Conv2D(32, kernel_size = (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Conv2D(64, kernel_size = (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Conv2D(64, kernel_size = (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Conv2D(32, kernel_size = (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Dropout(0.2))
classifier.add(Flatten())

classifier.add(Dense(units= 128, activation = 'relu'))
classifier.add(Dense(units= 1, activation = 'sigmoid'))

classifier.compile(optimizer='adam',loss="binary_crossentropy",metrics=["accuracy"])
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
step_train_size=training_set.n//training_set.batch_size
step_valid_size=validation_set.n//validation_set.batch_size

classifier.fit(training_set,
                    steps_per_epoch=step_train_size,
                    validation_data=validation_set,
                    validation_steps=step_valid_size,
                    epochs=50)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.13/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 0.9303 - loss: 0.2850 - val_accuracy: 0.9531 - val_loss: 0.1621
# Epoch 2/50
#  1/31 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 1.0000 - loss: 0.0457
# /usr/local/lib/python3.13/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 0.0457 - val_accuracy: 0.9531 - val_loss: 0.1683
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 324ms/step - accuracy: 0.9615 - loss: 0.1463 - val_accuracy: 0.9500 - val_loss: 0.1827
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9062 - loss: 0.2740 - val_accuracy: 0.9594 - val_loss: 0.1455
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 350ms/step - accuracy: 0.9605 - loss: 0.1423 - val_accuracy: 0.9500 - val_loss: 0.1717
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9375 - loss: 0.1963 - val_accuracy: 0.9531 - val_loss: 0.1675
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 16s 282ms/step - accuracy: 0.9584 - loss: 0.1485 - val_accuracy: 0.9500 - val_loss: 0.1717
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 0.0361 - val_accuracy: 0.9500 - val_loss: 0.1790
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.9625 - loss: 0.1353 - val_accuracy: 0.9531 - val_loss: 0.1645
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8750 - loss: 0.3033 - val_accuracy: 0.9500 - val_loss: 0.1742
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 204ms/step - accuracy: 0.9584 - loss: 0.1399 - val_accuracy: 0.9531 - val_loss: 0.1509
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 0.9531 - val_loss: 0.1477
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 285ms/step - accuracy: 0.9594 - loss: 0.1093 - val_accuracy: 0.9500 - val_loss: 0.1270
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9688 - loss: 0.0808 - val_accuracy: 0.9500 - val_loss: 0.1231
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 210ms/step - accuracy: 0.9594 - loss: 0.1589 - val_accuracy: 0.9500 - val_loss: 0.1180
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9688 - loss: 0.0654 - val_accuracy: 0.9500 - val_loss: 0.1169
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 330ms/step - accuracy: 0.9594 - loss: 0.0950 - val_accuracy: 0.9500 - val_loss: 0.1055
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.9500 - val_loss: 0.1126
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9646 - loss: 0.0837 - val_accuracy: 0.9500 - val_loss: 0.0873
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 1.0000 - loss: 0.0359 - val_accuracy: 0.9531 - val_loss: 0.0816
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 328ms/step - accuracy: 0.9677 - loss: 0.0667 - val_accuracy: 0.9656 - val_loss: 0.0616
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9688 - loss: 0.1037 - val_accuracy: 0.9594 - val_loss: 0.0665
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 313ms/step - accuracy: 0.9750 - loss: 0.0577 - val_accuracy: 0.9531 - val_loss: 0.0693
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9062 - loss: 0.5549 - val_accuracy: 0.9719 - val_loss: 0.0625
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 16s 204ms/step - accuracy: 0.9709 - loss: 0.0705 - val_accuracy: 0.9688 - val_loss: 0.0557
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9375 - loss: 0.1903 - val_accuracy: 0.9719 - val_loss: 0.0558
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.9729 - loss: 0.0643 - val_accuracy: 0.9656 - val_loss: 0.0550
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9688 - loss: 0.0494 - val_accuracy: 0.9594 - val_loss: 0.0550
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 333ms/step - accuracy: 0.9771 - loss: 0.0578 - val_accuracy: 0.9781 - val_loss: 0.0496
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9688 - loss: 0.0402 - val_accuracy: 0.9750 - val_loss: 0.0521
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 358ms/step - accuracy: 0.9802 - loss: 0.0600 - val_accuracy: 0.9625 - val_loss: 0.0553
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9719 - val_loss: 0.0419
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 334ms/step - accuracy: 0.9802 - loss: 0.0564 - val_accuracy: 0.9656 - val_loss: 0.0497
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9375 - loss: 0.0922 - val_accuracy: 0.9688 - val_loss: 0.0446
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 378ms/step - accuracy: 0.9839 - loss: 0.0552 - val_accuracy: 0.9563 - val_loss: 0.0569
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 1.0000 - loss: 2.6486e-05 - val_accuracy: 0.9594 - val_loss: 0.0537
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - accuracy: 0.9834 - loss: 0.0511 - val_accuracy: 0.9750 - val_loss: 0.0499
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 8.6475e-04 - val_accuracy: 0.9688 - val_loss: 0.0534
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 0.9865 - loss: 0.0472 - val_accuracy: 0.9812 - val_loss: 0.0430
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9812 - val_loss: 0.0437
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9854 - loss: 0.0402 - val_accuracy: 0.9719 - val_loss: 0.0631
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9688 - loss: 0.0378 - val_accuracy: 0.9719 - val_loss: 0.0651
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - accuracy: 0.9854 - loss: 0.0437 - val_accuracy: 0.9844 - val_loss: 0.0531
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.0390 - val_accuracy: 0.9844 - val_loss: 0.0487
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step - accuracy: 0.9865 - loss: 0.0448 - val_accuracy: 0.9812 - val_loss: 0.0410
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 0.9781 - val_loss: 0.0409
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 305ms/step - accuracy: 0.9875 - loss: 0.0362 - val_accuracy: 0.9688 - val_loss: 0.0728
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 4.4720e-04 - val_accuracy: 0.9719 - val_loss: 0.0705
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 350ms/step - accuracy: 0.9854 - loss: 0.0464 - val_accuracy: 0.9875 - val_loss: 0.0512
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.9875 - val_loss: 0.0482

# %%
classifier.evaluate(validation_set, steps=step_valid_size)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9875 - loss: 0.0483
# [0.04826933145523071, 0.987500011920929]

# %%
step_test_size = test_set.n//test_set.batch_size
predicted_conditions = classifier.predict(test_set,steps=step_test_size, verbose=1)

predicted_class_indices=(predicted_conditions > 0.5).astype(int).flatten()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step

# %%
labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
print(predictions[0:10])
print(testset_df.head(10))
# Out:
# ['COPD', 'COPD', 'COPD', 'COPD', 'COPD', 'COPD', 'COPD', 'COPD', 'COPD', 'COPD']
#                               ID CLASS
# 1176  118_1b1_Lr_sc_Litt3200.jpg  COPD
# 264   178_1b2_Ar_mc_AKGC417L.jpg  COPD
# 589   130_2b4_Al_mc_AKGC417L.jpg  COPD
# 840   130_3b3_Ll_mc_AKGC417L.jpg  COPD
# 1123  162_2b4_Ar_mc_AKGC417L.jpg  COPD
# 730   200_3p4_Tc_mc_AKGC417L.jpg  COPD
# 1003  112_1p1_Ll_sc_Litt3200.jpg  COPD
# 620   203_2p3_Pl_mc_AKGC417L.jpg  COPD
# 1609  138_1p2_Al_mc_AKGC417L.jpg  COPD
# 1388  138_1p3_Lr_mc_AKGC417L.jpg  COPD
